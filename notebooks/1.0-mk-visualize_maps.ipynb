# %%
import os

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

from connectivity.visualization.visualize import PlotPred, MapPred
from connectivity import io
from connectivity.constants import Defaults, Dirs

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
# define dirs class
defaults = Defaults()

# get visualize config file
config = io.read_json(str(defaults.visualize_config))

# %%
## define class
map_pred = MapPred(config, view='browser', pred_type='S_best_weight')

map_pred.save_predictions_to_nifti()

# visualize group map
# map_pred.visualize_prediction_group()

# %%
# define class for plotting 
pred = PlotPred(eval_on=['sc1', 'sc2'], model_name='tesselsWB162_grey_nan_l2_regress')

# load dataframe
dataframe = pred.load_dataframe()

# plot graph
pred.plot_predictions(dataframe, filter_eval=['R_y', 'R_pred_cv', 'R_pred_ncv'], plot_params=True)
# Out:
# {'eval_X_file_dir': 'encoding',
#  'eval_X_roi': 'tesselsWB162',
#  'eval_X_structure': 'cortex',
#  'eval_Y_file_dir': 'encoding',
#  'eval_Y_roi': 'grey_nan',
#  'eval_Y_structure': 'cerebellum',
#  'eval_avg': 'run',
#  'eval_glm': 7,
#  'eval_good_vox': False,
#  'eval_incl_inst': True,
#  'eval_on': 'sc1',
#  'eval_save_maps': False,
#  'eval_scale': True,
#  'eval_sessions': [1, 2],
#  'eval_splitby': None,
#  'eval_splits': ['all-cond'],
#  'eval_stim': 'cond',
#  'eval_subjects': [2,
#                    3,
#                    4,
#                    6,
#                    8,
#                    9,
#                    10,
#                    12,
#                    14,
#                    15,
#                    17,
#                    18,
#                    19,
#                    20,
#                    21,
#                    22,
#                    24,
#                    25,
#                    26,
#                    27,
#                    28,
# ...
