# %%
import os

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from IPython.display import display

from connectivity.visualization.visualize import PlotPred, MapCerebellum, MapCortex
from connectivity import io
from connectivity.constants import Defaults, Dirs

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# @authors: Maedbh King

# %%
# define dirs class
defaults = Defaults()

# %%
# get visualize config file for cerebellum
config = io.read_json(str(defaults.visualize_cerebellum_config))

# define class for plotting on CEREBELLUM
map_pred = MapCerebellum(config, eval_on=['sc1', 'sc2'], eval_name='tesselsWB6162_grey_nan_l2_regress', view='browser', data_type='R_y')

map_pred.save_data_to_nifti()

# visualize group map
map_pred.visualize_group()

# %%
# define class for plotting 
pred = PlotPred(eval_on=['sc1', 'sc2'], eval_name=['tesselsWB162_grey_nan_l2_regress'], eval_avg='run', train_avg='run', eval_sparse_matrix=[False], train_mode=['crossed'])

# load dataframe
dataframe = pred.load_dataframe()

# plot graph
pred.plot_lineplot(dataframe, x='lambdas', y='eval', hue='eval_type', filter_eval=['R_pred_cv', 'R_pred_ncv', 'R_pred'], plot_params=True, forloop=None)

# pred.plot_barplot(dataframe, x='eval_X_roi', y='eval', hue='eval_type', filter_eval=['R_pred_cv', 'R_pred_ncv', 'R_y', 'R_pred'], plot_params=True, forloop=False)
# Out:
# {'eval_X_file_dir': 'encoding',
#  'eval_avg': 'run',
#  'eval_good_vox': True,
#  'eval_incl_inst': True,
#  'eval_name': ['tesselsWB162_grey_nan_l2_regress'],
#  'eval_on': ['sc1', 'sc2'],
#  'eval_scale': True,
#  'eval_sparse_matrix': [False],
#  'eval_stim': 'cond',
#  'glm': 7,
#  'lambdas': [1, 2, 6, 15, 36, 88, 215, 527, 1292, 3162],
#  'train_X_file_dir': 'encoding',
#  'train_avg': 'run',
#  'train_incl_inst': True,
#  'train_mode': ['crossed'],
#  'train_scale': True,
#  'train_stim': 'cond'}
