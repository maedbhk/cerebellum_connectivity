# %%
import os

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

from connectivity.visualization.visualize import PlotPred, MapPred
from connectivity import io
from connectivity.constants import Defaults, Dirs

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# @authors: Maedbh King
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# define dirs class
defaults = Defaults()

# get visualize config file
config = io.read_json(str(defaults.visualize_config))

# %%
## define class
map_pred = MapPred(config, eval_name='tesselsWB642_grey_nan_l2_regress', view='browser', pred_type='R_pred_cv')

map_pred.save_predictions_to_nifti()

# visualize group map
map_pred.visualize_prediction_group()
# Out:
# /Users/maedbhking/Documents/cerebellum_connectivity/data/sc1/conn_models/glm7/eval/tesselsWB642_grey_nan_l2_regress_2020-09-21_00:44:40.h5 does not have vox data
# /Users/maedbhking/Documents/cerebellum_connectivity/data/sc1/conn_models/glm7/eval/tesselsWB642_grey_nan_l2_regress_2020-09-21_02:56:43.h5 contains vox data
# /Users/maedbhking/Documents/cerebellum_connectivity/data/sc2/conn_models/glm7/eval/tesselsWB642_grey_nan_l2_regress_2020-09-21_02:54:54.h5 contains vox data
# /Users/maedbhking/Documents/cerebellum_connectivity/data/sc2/conn_models/glm7/eval/tesselsWB642_grey_nan_l2_regress_2020-09-21_00:27:58.h5 does not have vox data
# /Users/maedbhking/Documents/cerebellum_connectivity/data/sc1/conn_models/glm7/eval/tesselsWB642_grey_nan_l2_regress_2020-09-21_00:44:40.h5 does not have vox data
# /Users/maedbhking/Documents/cerebellum_connectivity/data/sc1/conn_models/glm7/eval/tesselsWB642_grey_nan_l2_regress_2020-09-21_02:56:43.h5 contains vox data
# ...

# %%
# define class for plotting 
pred = PlotPred(eval_on=['sc1'], eval_name=['tesselsWB162_grey_nan_l2_regress', 'tesselsWB362_grey_nan_l2_regress', 'tesselsWB642_grey_nan_l2_regress'])

# load dataframe
dataframe = pred.load_dataframe()

# plot graph
pred.plot_predictions(dataframe, x='lambdas', y='eval', hue='eval_type', filter_eval=['R_y', 'R_pred_cv', 'R_pred_ncv'], plot_params=True)

# pred.plot_predictions(dataframe, x='eval_X_roi', y='eval', hue='eval_type', filter_eval=['R_pred_ncv', 'R_pred_cv'], forloop=False, plot_params=True)

# pred.plot_predictions(dataframe, x='lambdas', y='eval', hue='eval_type', filter_eval=['R_pred_ncv', 'R_pred_cv'], forloop='eval_X_roi', plot_params=True)
