# %%
import os

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

from connectivity.visualization.visualize import PlotPred, MapPred
from connectivity import io
from connectivity.constants import Defaults, Dirs

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# define dirs class
defaults = Defaults()

# get visualize config file
config = io.read_json(str(defaults.visualize_config)))

# %%
## define class
map_pred = MapPred(config, view='browser', pred_type='S_best_weight')

# visualize group map
map_pred.visualize_prediction_group()
# Out:
# {'eval_avg': 'run',
#  'eval_glm': 7,
#  'eval_good_vox': False,
#  'eval_incl_inst': True,
#  'eval_inputs': {'eval_X': {'file_dir': 'encoding',
#                             'roi': 'tesselsWB162',
#                             'structure': 'cortex'},
#                  'eval_Y': {'file_dir': 'encoding',
#                             'roi': 'grey_nan',
#                             'structure': 'cerebellum'}},
#  'eval_on': 'sc1',
#  'eval_save_maps': True,
#  'eval_scale': True,
#  'eval_sessions': [1, 2],
#  'eval_splitby': None,
#  'eval_splits': ['all-cond'],
#  'eval_stim': 'cond',
#  'eval_subjects': [2,
#                    3,
#                    4,
#                    6,
#                    8,
#                    9,
#                    10,
#                    12,
#                    14,
#                    15,
#                    17,
#                    18,
#                    19,
#                    20,
#                    21,
#                    22,
#                    24,
#                    25,
#                    26,
#                    27,
#                    28,
#                    29,
#                    30,
#                    31],
#  'eval_subtract_exp_mean': True,
#  'eval_subtract_sess_mean': True,
#  'lambdas': [500],
#  'model_fname': 'tesselsWB162_grey_nan_l2_regress_2020-09-09_17:12:52.json',
#  'model_name': 'l2_regress',
#  'train_avg': 'run',
#  'train_glm': 7,
#  'train_incl_inst': True,
#  'train_inputs': {'train_X': {'file_dir': 'encoding',
#                               'roi': 'tesselsWB162',
#                               'structure': 'cortex'},
#                   'train_Y': {'file_dir': 'encoding',
#                               'roi': 'grey_nan',
#                               'structure': 'cerebellum'}},
#  'train_mode': 'crossed',
#  'train_on': 'sc2',
#  'train_scale': True,
#  'train_sessions': [1, 2],
#  'train_stim': 'cond',
#  'train_subjects': [2,
#                     3,
#                     4,
#                     6,
#                     8,
#                     9,
#                     10,
#                     12,
#                     14,
#                     15,
#                     17,
#                     18,
#                     19,
#                     20,
#                     21,
#                     22,
#                     24,
#                     25,
#                     26,
#                     27,
#                     28,
#                     29,
#                     30,
#                     31],
#  'train_subtract_exp_mean': True,
#  'train_subtract_sess_mean': True}
# {'eval_avg': 'run',
#  'eval_glm': 7,
#  'eval_good_vox': False,
#  'eval_incl_inst': True,
#  'eval_inputs': {'eval_X': {'file_dir': 'encoding',
#                             'roi': 'tesselsWB162',
#                             'structure': 'cortex'},
#                  'eval_Y': {'file_dir': 'encoding',
#                             'roi': 'grey_nan',
#                             'structure': 'cerebellum'}},
#  'eval_on': 'sc2',
#  'eval_save_maps': True,
#  'eval_scale': True,
#  'eval_sessions': [1, 2],
#  'eval_splitby': None,
#  'eval_splits': ['all-cond'],
#  'eval_stim': 'cond',
#  'eval_subjects': [2,
#                    3,
#                    4,
#                    6,
#                    8,
#                    9,
#                    10,
#                    12,
#                    14,
#                    15,
#                    17,
#                    18,
#                    19,
#                    20,
#                    21,
#                    22,
#                    24,
#                    25,
#                    26,
#                    27,
#                    28,
#                    29,
#                    30,
#                    31],
#  'eval_subtract_exp_mean': True,
#  'eval_subtract_sess_mean': True,
#  'lambdas': [500],
#  'model_fname': 'tesselsWB162_grey_nan_l2_regress_2020-09-09_17:11:20.json',
#  'model_name': 'l2_regress',
#  'train_avg': 'run',
#  'train_glm': 7,
#  'train_incl_inst': True,
#  'train_inputs': {'train_X': {'file_dir': 'encoding',
#                               'roi': 'tesselsWB162',
#                               'structure': 'cortex'},
#                   'train_Y': {'file_dir': 'encoding',
#                               'roi': 'grey_nan',
#                               'structure': 'cerebellum'}},
#  'train_mode': 'crossed',
#  'train_on': 'sc1',
#  'train_scale': True,
#  'train_sessions': [1, 2],
#  'train_stim': 'cond',
#  'train_subjects': [2,
#                     3,
#                     4,
#                     6,
#                     8,
#                     9,
#                     10,
#                     12,
#                     14,
#                     15,
#                     17,
#                     18,
#                     19,
#                     20,
#                     21,
#                     22,
#                     24,
#                     25,
#                     26,
#                     27,
#                     28,
#                     29,
#                     30,
#                     31],
#  'train_subtract_exp_mean': True,
#  'train_subtract_sess_mean': True}

# %%
# define class for plotting 
pred = PlotPred()

# load dataframe
dataframe = pred.load_dataframe()

# plot graph
pred.plot_predictions(dataframe, plot_params=False, filter_eval=['R_y', 'R_pred_crossed', 'R_pred_uncrossed'])
