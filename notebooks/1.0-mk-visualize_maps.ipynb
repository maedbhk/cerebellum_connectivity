# %%
import os

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

from connectivity.visualization.visualize import PlotPred, MapCerebellum, MapCortex
from connectivity import io
from connectivity.constants import Defaults, Dirs

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# @authors: Maedbh King
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# define dirs class
defaults = Defaults()

# %%
# get visualize config file for cerebellum
config = io.read_json(str(defaults.visualize_cerebellum_config))

# define class for plotting on CEREBELLUM
map_pred = MapCerebellum(config, eval_on=['sc2'], eval_name='tesselsWB362_grey_nan_l2_regress', view='browser', data_type='R_high')

map_pred.save_data_to_nifti()

# visualize group map
map_pred.visualize_group()
# Out:
# /Users/maedbhking/Documents/cerebellum_connectivity/data/sc2/conn_models/glm7/eval/tesselsWB362_grey_nan_l2_regress_2020-09-23_00:22:15.h5 does not have vox data
# /Users/maedbhking/Documents/cerebellum_connectivity/data/sc2/conn_models/glm7/eval/tesselsWB362_grey_nan_l2_regress_2020-09-23_00:41:51.h5 contains vox data
# /Users/maedbhking/Documents/cerebellum_connectivity/data/sc2/conn_models/glm7/eval/tesselsWB362_grey_nan_l2_regress_2020-09-23_00:17:44.h5 does not have vox data
# /Users/maedbhking/Documents/cerebellum_connectivity/data/sc2/conn_models/glm7/eval/tesselsWB362_grey_nan_l2_regress_2020-09-23_00:14:20.h5 does not have vox data
# /Users/maedbhking/Documents/cerebellum_connectivity/data/sc2/conn_models/glm7/eval/tesselsWB362_grey_nan_l2_regress_2020-09-23_00:22:15.h5 does not have vox data
# /Users/maedbhking/Documents/cerebellum_connectivity/data/sc2/conn_models/glm7/eval/tesselsWB362_grey_nan_l2_regress_2020-09-23_00:41:51.h5 contains vox data
# /Users/maedbhking/Documents/cerebellum_connectivity/data/sc2/conn_models/glm7/eval/tesselsWB362_grey_nan_l2_regress_2020-09-23_00:17:44.h5 does not have vox data
# /Users/maedbhking/Documents/cerebellum_connectivity/data/sc2/conn_models/glm7/eval/tesselsWB362_grey_nan_l2_regress_2020-09-23_00:14:20.h5 does not have vox data
# {'eval_X_file_dir': 'encoding',
#  'eval_X_roi': 'tesselsWB362',
#  'eval_X_structure': 'cortex',
#  'eval_Y_file_dir': 'encoding',
#  'eval_Y_roi': 'grey_nan',
#  'eval_Y_structure': 'cerebellum',
#  'eval_avg': 'run',
#  'eval_glm': 7,
#  'eval_good_vox': False,
#  'eval_incl_inst': True,
#  'eval_on': 'sc2',
#  'eval_save_maps': True,
#  'eval_scale': True,
#  'eval_sessions': [1, 2],
#  'eval_sparse_matrix': False,
#  'eval_splitby': None,
#  'eval_splits': ['all-cond'],
#  'eval_stim': 'cond',
#  'eval_subjects': [3, 4, 6],
#  'eval_subtract_exp_mean': True,
#  'eval_subtract_sess_mean': True,
#  'lambdas': [1000],
#  'model_fname': 'tesselsWB362_grey_nan_l2_regress_2020-09-23_00:41:29.json',
#  'model_name': 'l2_regress',
#  'train_X_file_dir': 'encoding',
#  'train_X_roi': 'tesselsWB362',
#  'train_X_structure': 'cortex',
#  'train_Y_file_dir': 'encoding',
#  'train_Y_roi': 'grey_nan',
#  'train_Y_structure': 'cerebellum',
#  'train_avg': 'run',
#  'train_glm': 7,
#  'train_incl_inst': True,
#  'train_mode': 'crossed',
#  'train_on': 'sc1',
#  'train_scale': True,
#  'train_sessions': [1, 2],
#  'train_stim': 'cond',
#  'train_subjects': [3, 4, 6],
#  'train_subtract_exp_mean': True,
#  'train_subtract_sess_mean': True}
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-188-48e3beea5e2b> in <module>
#       8
#       9 # visualize group map
# ---> 10 map_pred.visualize_group()
#
# ~/Documents/cerebellum_connectivity/connectivity/visualization/visualize.py in visualize_group(self)
#     317                 # get gifti files for `eval_name`, `subj`, `exp`, `data_type`
#     318                 data_type = self.config['data_type']
# --> 319                 gifti_fpath = self.get_all_files(fullpath=os.path.join(eval_dir, 'group'), wildcard=f'*{data_type}_vox.gii*')[0]
#     320
#     321                 if os.path.exists(gifti_fpath):
#
# IndexError: list index out of range

# %%
# define class for plotting 
pred = PlotPred(eval_on=['sc2'], eval_name=['tesselsWB362_grey_nan_l2_regress'])

# load dataframe
dataframe = pred.load_dataframe()

# plot graph
pred.plot_predictions(dataframe, x='lambdas', y='eval', hue='eval_type', filter_eval=['R_high', 'R_low', 'R_pred_cv', 'R_pred_ncv'], plot_params=True, forloop=None)

# pred.plot_predictions(dataframe, x='eval_X_roi', y='eval', hue='eval_type', filter_eval=['R_pred_ncv', 'R_pred_cv'], forloop=False, plot_params=True)

# pred.plot_predictions(dataframe, x='lambdas', y='eval', hue='eval_type', filter_eval=['R_pred_ncv', 'R_pred_cv'], forloop='eval_X_roi', plot_params=True)
# Out:
# {'eval_X_file_dir': 'encoding',
#  'eval_X_roi': 'tesselsWB362',
#  'eval_X_structure': 'cortex',
#  'eval_Y_file_dir': 'encoding',
#  'eval_Y_roi': 'grey_nan',
#  'eval_Y_structure': 'cerebellum',
#  'eval_avg': 'run',
#  'eval_glm': 7,
#  'eval_good_vox': False,
#  'eval_incl_inst': True,
#  'eval_name': ['tesselsWB362_grey_nan_l2_regress'],
#  'eval_on': ['sc2'],
#  'eval_save_maps': False,
#  'eval_scale': True,
#  'eval_sessions': [1, 2],
#  'eval_sparse_matrix': False,
#  'eval_splitby': None,
#  'eval_stim': 'cond',
#  'eval_subjects': [2,
#                    3,
#                    4,
#                    6,
#                    8,
#                    9,
#                    10,
#                    12,
#                    14,
#                    15,
#                    17,
#                    18,
#                    19,
#                    20,
#                    21,
#                    22,
#                    24,
#                    25,
#                    26,
#                    27,
#                    28,
#                    29,
#                    30,
#                    31],
#  'eval_subtract_exp_mean': True,
#  'eval_subtract_sess_mean': True,
#  'glm': 7,
#  'model_name': 'l2_regress',
#  'train_X_file_dir': 'encoding',
#  'train_X_roi': 'tesselsWB362',
#  'train_X_structure': 'cortex',
#  'train_Y_file_dir': 'encoding',
#  'train_Y_roi': 'grey_nan',
#  'train_Y_structure': 'cerebellum',
#  'train_avg': 'run',
#  'train_glm': 7,
#  'train_incl_inst': True,
#  'train_mode': 'crossed',
#  'train_on': 'sc1',
#  'train_scale': True,
#  'train_sessions': [1, 2],
#  'train_stim': 'cond',
#  'train_subjects': [2,
#                     3,
#                     4,
#                     6,
#                     8,
#                     9,
#                     10,
#                     12,
#                     14,
#                     15,
#                     17,
#                     18,
#                     19,
#                     20,
#                     21,
#                     22,
#                     24,
#                     25,
#                     26,
#                     27,
#                     28,
#                     29,
#                     30,
#                     31],
#  'train_subtract_exp_mean': True,
#  'train_subtract_sess_mean': True}
