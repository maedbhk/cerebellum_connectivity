# %%
import os

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from IPython.display import display

from connectivity.visualization.visualize import PlotPred, MapCerebellum, MapCortex
from connectivity import io
from connectivity.constants import Defaults, Dirs

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# @authors: Maedbh King
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# define dirs class
defaults = Defaults()

# %%
# get visualize config file for cerebellum
config = io.read_json(str(defaults.visualize_cerebellum_config))

# define class for plotting on CEREBELLUM
map_pred = MapCerebellum(config, eval_on=['sc1', 'sc2'], eval_name='tesselsWB6162_grey_nan_l2_regress', view='browser', data_type='wta')

# visualize group map
map_pred.visualize_group()

# %%
# define class for plotting 
pred = PlotPred(eval_on=['sc1'], eval_name=['tesselsWB162_grey_nan_l2_regress', 'tesselsWB162_grey_nan_linear_model'], eval_sparse_matrix=[False, True], eval_avg='run', train_avg='run', train_mode=['crossed'])

# load dataframe
dataframe = pred.load_dataframe()

# plot graph
pred.plot_lineplot(dataframe, x='lambdas', y='eval', hue='eval_type', filter_eval=['R_pred_cv', 'R_y'], plot_params=False, forloop=None, ci=40)

# pred.plot_barplot(dataframe, x='eval_X_roi', y='eval', hue='eval_type', filter_eval=['R_pred_cv', 'R_pred_ncv', 'R_y', 'R_pred'], plot_params=False, forloop=False)
# Out:
# &lt;Figure size 662.875x288 with 1 Axes&gt;
