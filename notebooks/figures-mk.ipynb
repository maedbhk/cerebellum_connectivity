# %%
import connectivity.figures as fig

# %reload_ext autoreload
# %autoreload 2

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
# Out:
# /Users/maedbhking/.local/share/virtualenvs/cerebellum_connectivity-DbxULmID/lib/python3.7/site-packages/nilearn/datasets/__init__.py:90: FutureWarning: Fetchers from the nilearn.datasets module will be updated in version 0.9 to return python strings instead of bytes and Pandas dataframes instead of Numpy arrays.
#   "Numpy arrays.", FutureWarning)

# %%
fig.fig2()
# Out:
# F test for evaluation between lasso and ridge for TESSELS is: Ttest_relResult(statistic=array([1.279465, 10.936781, 7.130690, 12.834385, 14.632522]), pvalue=array([0.213491, 0.000000, 0.000000, 0.000000, 0.000000]))
# F test for evaluation between WTA and ridge for YEO is: Ttest_relResult(statistic=array([3.035986]), pvalue=array([0.005872]))
# F test for evaluation between WTA and ridge for TESSELS is: Ttest_relResult(statistic=array([4.127167, 8.930253, 10.680442, 13.766631, 13.147189]), pvalue=array([0.000410, 0.000000, 0.000000, 0.000000, 0.000000]))

# %%
fig.fig3()

# %%
# fig.fig3B()
# Out:
# F test for surfaces is F_onewayResult(statistic=2.296566924740184, pvalue=0.017362813898533974)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-b91ef5527a61> in <module>
# ----> 1 fig.fig3B()
#
# ~/Documents/cerebellum_connectivity/connectivity/figures.py in fig3B()
#     370
#     371     ax = fig.add_subplot(gs[1,1:])
# --> 372     ax,df = vis.plot_dispersion(y='var_w', hue=None, y_label='cortical dispersion', method='lasso', cortex='tessels0362', atlas='MDTB10', regions=None, ax=ax);
#     373     # ax.text(x_pos, y_pos, 'C', transform=ax.transAxes, fontsize=labelsize, verticalalignment='top')
#     374     plt.ylim([0.6, 0.8])
#
# ~/Documents/cerebellum_connectivity/connectivity/visualize.py in plot_dispersion(exp, y, y_label, x_label, cortex, cortex_group, atlas, method, hue, plt_legend, regions, save, ax)
# ...

# %%
fig.fig4()
# Out:
# F test for evaluation between wta and ridge for TESSELS is: Ttest_relResult(statistic=array([1.493451, 1.818899, 2.148330, 2.430916]), pvalue=array([0.151740, 0.084725, 0.044794, 0.025132]))

# %%
fig.figS1()
