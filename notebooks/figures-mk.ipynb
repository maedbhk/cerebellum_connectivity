# %%
import connectivity.figures as fig

# %reload_ext autoreload
# %autoreload 2

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
fig.fig2()

# %%
fig.fig3()
# Out:
# best model for sc1 is ridge_tessels1002_alpha_8
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/.local/share/virtualenvs/cerebellum_connectivity-DbxULmID/lib/python3.7/site-packages/nibabel/loadsave.py in load(filename, **kwargs)
#      41     try:
# ---> 42         stat_result = os.stat(filename)
#      43     except OSError:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/maedbhking/Documents/cerebellum_connectivity/data/sc1/conn_models/train/ridge_tessels1002_alpha_8/group_MDTB10_threshold_100.L.func.gii'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-77869e93cd2a> in <module>
# ----> 1 fig.fig3()
#
# ~/Documents/cerebellum_connectivity/connectivity/figures.py in fig3(format)
# ...
