# %%
import connectivity.figures as fig

# %reload_ext autoreload
# %autoreload 2

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
fig.fig2()
# Out:
# F test for evaluation between lasso and ridge is: Ttest_relResult(statistic=array([-1.279465, -10.936781, -7.130690, -12.834385, -14.632522]), pvalue=array([0.213491, 0.000000, 0.000000, 0.000000, 0.000000]))
# F test for evaluation between WTA and ridge is: Ttest_relResult(statistic=array([-4.127167, -8.930253, -10.680442, -13.766631, -13.147189]), pvalue=array([0.000410, 0.000000, 0.000000, 0.000000, 0.000000]))
# F test for evaluation between lasso and ridge is: Ttest_relResult(statistic=array([-5.535198, -10.554376, -12.029338, -4.595822, -10.837295,
#        -11.625145, -5.459697, -14.334356, -13.771688, -12.012653,
#        -7.904122, -6.248276]), pvalue=array([0.000012, 0.000000, 0.000000, 0.000127, 0.000000, 0.000000,
#        0.000015, 0.000000, 0.000000, 0.000000, 0.000000, 0.000002]))
# F test for evaluation between WTA and ridge is: Ttest_relResult(statistic=array([-2.981079, -7.137089, -7.959731, -2.620866, -6.925993, -7.999382,
# ...

# %%
fig.fig3()

# %%
fig.fig3B()
# Out:
# F test for surfaces is F_onewayResult(statistic=2.296566924740184, pvalue=0.017362813898533974)
# F test for dispersion is F_onewayResult(statistic=2.4475554745679937, pvalue=0.011174279936649805)

# %%
# fig.fig5()
